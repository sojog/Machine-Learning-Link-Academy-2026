# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zalando-research/fashionmnist", output_dir="./fashion")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 68.8M/68.8M [01:55<00:00, 627kB/s]
# Extracting files...
# Path to dataset files: ./fashion
