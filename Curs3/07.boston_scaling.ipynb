# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("puxama/bostoncsv", output_dir="Boston_datasets")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("puxama/bostoncsv", output_dir="Boston_datasets")
#       6 print("Path to dataset files:", path)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/kagglehub/datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Boston_datasets/Boston.csv", index_col=0)
df
# Out:
#         crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 1    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 2    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 3    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 4    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 5    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 502  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 503  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 504  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# 505  0.10959   0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48  22.0
# 506  0.04741   0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              crim          zn       indus  ...       black       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]
