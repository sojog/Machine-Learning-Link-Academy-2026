# %%
import pandas as pd

# Define simple keyword lists
positive_words = ["great", "excellent", "amazing", "love", "perfect", "good", "fantastic", "happy", "recommend"]
negative_words = ["bad", "terrible", "worst", "broken", "poor", "disappointed", "awful", "hate", "slow"]

# Define a simple rule-based sentiment classifier (binary only)
def classify_sentiment(text):
    text = str(text).lower()
    pos_hits = sum(word in text for word in positive_words)
    neg_hits = sum(word in text for word in negative_words)

    if pos_hits >= neg_hits:
        return "positive"
    else:
        return "negative"

# Load labeled dataset
df = pd.read_csv("data/reviews_labeled_cleaned.csv")

# Apply the classifier
df['predicted_sentiment'] = df['review'].apply(classify_sentiment)

# Save the results to a new CSV file
df.to_csv("data/reviews_with_predicted_sentiment.csv", index=False)

# Display sample output in the terminal (only selected columns)
print(df[['review', 'sentiment', 'predicted_sentiment']].head(20))
# Out:
#                                                review sentiment  \
# 0   camera quality is very very poor not look like...  negative
# 1   leaking from the big neck cap whike mixing the...  negative
# 2   performance not well its taking too much time ...  negative
# 3                                 not better but okay  negative
# 4   product quality is very poor its made of some ...  negative
# 5                              very excellent product  positive
# 6                 not worth for the price low quality  negative
# 7                    useless one not even1 used once   negative
# 8                                                nice  positive
# 9   sound and bass quality is very poor i want to ...  negative
# 10                                          very good  positive
# 11                             i am feeling very well  positive
# 12  power backup could have been better takes too ...  positive
# 13                                               good  positive
# ...

# %% [markdown]
# # Definirea noilor coloane și a logicii:
# # - Folosim funcția classify_sentiment(text) pe care am creat-o mai devreme; aceasta face o „mini verificare” pentru fiecare recenzie: numără aparițiile cuvintelor pozitive și negative.
# # - Regula „mai multe sau egal cu cuvinte pozitive → positive, mai multe negative → negative” este intenționat simplificată, dar demonstrează principiul de bază al „votului”.
# Aplicarea pe setul de date:
# # - df['predicted_sentiment'] = df['review'].apply(classify_sentiment)
# Această linie trece PRIN TOATE recenziile și aplică funcția noastră pe fiecare, completând automat o coloană nouă cu sentimentul prevăzut.
#
# # Înregistrarea rezultatelor:
# # - df.to_csv("data/reviews_with_predicted_sentiment.csv", index=False)
# # Acum avem un fișier separat în care, lângă fiecare sentiment original, apare și „verdictul” sistemului nostru – gata pentru comparare cu valoarea reală din coloana sentiment.
#
# # Afișarea unui eșantion din rezultate:
# # Folosim funcțiile print() și head() pentru a afișa primele 20 de recenzii, etichetate cu sistemul nostru. Astfel, putem imediat să avem o impresie despre succesul funcționării sale – fără să deschidem un fișier CSV nou.
