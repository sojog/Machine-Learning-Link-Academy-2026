# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
plt.scatter(x, y)

# %% [markdown]
# # Proportia - antrenez (train) cu 80%
# # Proportia - evaluez (test) cu 20%

# %%
x_train = x[:80]
y_train = y[:80]


x_test = x[80:]
y_test = y[80:]

plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)

# %%
x_train = x[:50]
y_train = y[:50]


x_test = x[50:]
y_test = y[50:]

plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)

# %%
x_train = x[:80]
y_train = y[:80]


x_test = x[80:]
y_test = y[80:]

plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([ -21.22391595,  -85.80619766,   21.73841149, -108.60332152,
#          75.10176444, -159.87439306,  -20.61459792,  -21.13310644,
#           8.01636162,  -84.71078385,   53.50382627,  -58.82413085,
#          43.59264981,   60.85450817,  -81.27664612,  147.11623686,
#          17.73646628,  124.14712134,  -52.1092279 ,   70.19201172])

# %%
y_test
# Out:
# array([ -17.66657472,  -88.2238531 ,   12.73561741, -101.6814593 ,
#          63.23134547, -176.07494299,  -16.57422729,  -30.44130481,
#           0.8557586 ,  -80.19532201,   56.52999459,  -66.52551356,
#          29.07380238,   57.90121903,  -76.76176029,  144.32135098,
#          24.5396055 ,  119.58483336,  -21.33051804,   77.42892856])

# %%
model.score(x_test, y_test)
# Out:
# 0.9825352499572634

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.9636289766172522
