# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# (mp, pret)


apartamente = np.array([(37, 62_000), (45, 57_000), (50, 80_000), (72, 155_000), (80, 170_000), (90, 110_000), (250, 400_000), (500, 1_200_000)])
apartamente
# Out:
# array([[     37,   62000],
#        [     45,   57000],
#        [     50,   80000],
#        [     72,  155000],
#        [     80,  170000],
#        [     90,  110000],
#        [    250,  400000],
#        [    500, 1200000]])

# %%
suprafete = apartamente[ :, 0 ]
preturi = apartamente[ :, 1 ]

# %%
plt.scatter(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
# Out:
# Text(0, 0.5, 'Preturi')

# %% [markdown]
# # Varianta cu scipy

# %%
from scipy.stats import linregress

# %%
x, y = suprafete, preturi

regress_result = linregress(x, y)
regress_result
# Out:
# LinregressResult(slope=np.float64(2384.8331446080065), intercept=np.float64(-55819.05681742489), rvalue=np.float64(0.9856514094516687), pvalue=np.float64(7.3060447823362205e-06), stderr=np.float64(166.73053818516158), intercept_stderr=np.float64(34275.090784912514))

# %%
a = regress_result.slope
b = regress_result.intercept

# %%
a = 2200 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)

plt.xlabel("Suprafete")
plt.ylabel("Preturi")


a = regress_result.slope
b = regress_result.intercept

preturi_scipy = a * suprafete + b
preturi_scipy

plt.plot(suprafete, preturi_scipy)

# %% [markdown]
# # Varianta cu sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
x # suprafata
# Out:
# array([ 37,  45,  50,  72,  80,  90, 250, 500])

# %%
# [ [37],  [45],  [50],  [72],  [80,  90, 250, 500]

# %%
suprafete
# Out:
# array([ 37,  45,  50,  72,  80,  90, 250, 500])

# %%
suprafete_2d = suprafete.reshape(-1, 1)
suprafete_2d
# Out:
# array([[ 37],
#        [ 45],
#        [ 50],
#        [ 72],
#        [ 80],
#        [ 90],
#        [250],
#        [500]])

# %%
x = suprafete_2d

# %%
y
# Out:
# array([  62000,   57000,   80000,  155000,  170000,  110000,  400000,
#        1200000])

# %%
x, y = suprafete_2d, preturi
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(-55819.05681742495)

# %%
model.coef_ # sklearn
# Out:
# array([2384.83314461])

# %%
regress_result.slope
# Out:
# np.float64(2384.8331446080065)

# %%
regress_result.intercept
# Out:
# np.float64(-55819.05681742489)

# %%
def f(x):
    a = regress_result.slope
    b = regress_result.intercept
    return a * x + b

# %%
model.predict([  [73], [80]  ])
# Out:
# array([118273.76273896, 134967.59475122])
