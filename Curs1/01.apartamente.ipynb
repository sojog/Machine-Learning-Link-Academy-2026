# %%
100_000, 1000000
# Out:
# (100000, 1000000)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# (mp, pret)


apartamente = np.array([(37, 62_000), (45, 57_000), (50, 80_000), (72, 155_000), (80, 170_000), (90, 110_000), (250, 400_000), (500, 1_200_000)])
apartamente
# Out:
# array([[     37,   62000],
#        [     45,   57000],
#        [     50,   80000],
#        [     72,  155000],
#        [     80,  170000],
#        [     90,  110000],
#        [    250,  400000],
#        [    500, 1200000]])

# %%
suprafete = apartamente[ :, 0 ]
suprafete
# Out:
# array([ 37,  45,  50,  72,  80,  90, 250, 500])

# %%
preturi = apartamente[ :, 1 ]
preturi
# Out:
# array([  62000,   57000,   80000,  155000,  170000,  110000,  400000,
#        1200000])

# %%
plt.scatter(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
# Out:
# Text(0, 0.5, 'Preturi')

# %%
plt.scatter(suprafete[:-1], preturi[:-1])
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
# Out:
# Text(0, 0.5, 'Preturi')

# %%
plt.scatter(suprafete[:-2], preturi[:-2])
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
# Out:
# Text(0, 0.5, 'Preturi')

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
# Out:
# Text(0, 0.5, 'Preturi')

# %%
def f(x):
    a = 1 
    b = 2
    return a * x + b


f(1), f(2), f(3)
# Out:
# (3, 4, 5)

# %%
suprafete
# Out:
# array([ 37,  45,  50,  72,  80,  90, 250, 500])

# %%
list(map(f, suprafete))
# Out:
# [np.int64(39),
#  np.int64(47),
#  np.int64(52),
#  np.int64(74),
#  np.int64(82),
#  np.int64(92),
#  np.int64(252),
#  np.int64(502)]

# %%
a = 1 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise
# Out:
# array([ 39,  47,  52,  74,  82,  92, 252, 502])

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete, preturi_prezise)

# %%
a = 1000 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete, preturi_prezise)

# %%
a = 2000 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete, preturi_prezise)

# %%
a = 2500 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete, preturi_prezise)

# %%
a = 2200 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete, preturi_prezise)

# %% [markdown]
# # pip install scipy

# %%
from scipy.stats import linregress

# %%
x, y = suprafete, preturi

regress_result = linregress(x, y)
regress_result
# Out:
# LinregressResult(slope=np.float64(2384.8331446080065), intercept=np.float64(-55819.05681742489), rvalue=np.float64(0.9856514094516687), pvalue=np.float64(7.3060447823362205e-06), stderr=np.float64(166.73053818516158), intercept_stderr=np.float64(34275.090784912514))

# %%
a = regress_result.slope
b = regress_result.intercept

# %%
a = 2200 
b = 2
preturi_prezise = a * suprafete + b
preturi_prezise

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
plt.xlabel("Suprafete")
plt.ylabel("Preturi")
plt.plot(suprafete, preturi_prezise)

a = regress_result.slope
b = regress_result.intercept

preturi_scipy = a * suprafete + b
preturi_scipy

plt.plot(suprafete, preturi_scipy)

# %%
plt.scatter(suprafete, preturi)

plt.xlabel("Suprafete")
plt.ylabel("Preturi")


preturi_scipy = a * suprafete + b
preturi_scipy

plt.plot(suprafete, preturi_scipy)

# %%
def f(x):
    a = regress_result.slope
    b = regress_result.intercept
    return  a * x + b

# %%
f(66)
# Out:
# np.float64(101579.93072670355)

# %%
plt.scatter(suprafete, preturi)

plt.xlabel("Suprafete")
plt.ylabel("Preturi")


preturi_scipy = a * suprafete + b
preturi_scipy

plt.plot(suprafete, preturi_scipy)

plt.scatter(66, f(66))
plt.scatter(200, f(200))

# %%
result = linregress(suprafete[:-2], preturi[:-2])

plt.scatter(suprafete[:-2], preturi[:-2])
plt.plot(suprafete[:-2], preturi[:-2])
plt.xlabel("Suprafete")
plt.ylabel("Preturi")

plt.plot(suprafete[:-2] , result.slope * suprafete[:-2] + result.intercept  )
